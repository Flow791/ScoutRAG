# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import config

# %%
import random
import json
from pathlib import Path
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
import pandas as pd
from tqdm import tqdm
from openai import OpenAI
import re, math, unicodedata

# %%
client = OpenAI(api_key=config.Config.OPENAI_API_KEY)
qdrant_client = QdrantClient(url='localhost')
embedding_model = SentenceTransformer("BAAI/bge-m3")
collection_name = 'ragscout_players'
path = Path("../../data/player_queries.json")
random.seed(10)

sample_size = 100

GAIN_EXACT_PLAYER = 4
GAIN_PROFIL_EQUAL = 3
GAIN_PROFIL_STRONG_OVERLAP = 2
GAIN_PROFIL_WEAK_OVERLAP = 1

# %%
def sample_players_from_qdrant(qdrant_client, collection_name, n=sample_size):
    players, all_points = [], []
    next_page = None
    while True:
        points, next_page = qdrant_client.scroll(
            collection_name=collection_name,
            with_payload=True, with_vectors=False,
            limit=256, offset=next_page
        )
        all_points.extend(points)
        if not next_page:
            break
        
    random.shuffle(all_points)
    seen = set()
    for p in all_points:
        payload = p.payload or {}
        name = payload.get("player")
        if name and payload.get("summary") and not name in seen:
            seen.add(name)
            players.append(payload)
            if len(players) >= n:
                break

    return players

players_sample = sample_players_from_qdrant(qdrant_client, collection_name, n=sample_size)
len(players_sample), players_sample[0].get("player"), players_sample[0].get("summary")[:120]
# Out:
# (100,
#  'Nadiem Amiri',
#  'Le joueur évolue principalement au poste de milieu de terrain, avec un sous-rôle qui pourrait être défini comme milieu c')

# %%
def extract_profil_type(summary: str) -> str | None:
    if not summary:
        return None
    
    m = re.search(r"Profil-type\s*:\s*(.+)", summary, flags=re.IGNORECASE)
    return m.group(1).strip() if m else None

def strip_accents(s: str) -> str:
    return "".join(c for c in unicodedata.normalize("NFD", s) if unicodedata.category(c) != "Mn")

def normalize_text(s: str) -> str:
    s = strip_accents(s.lower())
    s = s.replace(' et ', ' ').replace(' de ', ' ')
    s = re.sub(r"[^\w\s\-+]", " ", s)  # garde mots/espaces/tirets/+
    s = re.sub(r"\s+", " ", s).strip()
    return s

CANON_MAP = {}

def canonical_tokens(s: str) -> set:
    s = normalize_text(s)
    s = s.replace("duels aeriens", "aerien").replace("jeu entre les lignes", "entre-lignes")
    toks = set(s.split())
    return toks #set(CANON_MAP.get(t, t) for t in toks)

def soft_label(ref_profil: str | None, cand_profil: str | None) -> int:
    """
    2 = égal (après normalisation), 1 = au moins 1 token canonique partagé, 0 sinon
    """
    if not ref_profil or not cand_profil:
        return 0
    if normalize_text(ref_profil) == normalize_text(cand_profil):
        return GAIN_PROFIL_EQUAL
    if len(canonical_tokens(ref_profil) & canonical_tokens(cand_profil)) >= 3:
        return GAIN_PROFIL_STRONG_OVERLAP
    return GAIN_PROFIL_WEAK_OVERLAP if len(canonical_tokens(ref_profil) & canonical_tokens(cand_profil)) >= 2 else 0

def ndcg_at_k(gains: list[int], k: int) -> float:
    gains = gains[:k]
    dcg = sum(g / math.log2(i+2) for i, g in enumerate(gains))
    ideal = sorted(gains, reverse=True)
    idcg = sum(g / math.log2(i+2) for i, g in enumerate(ideal))
    return (dcg / idcg) if idcg > 0 else 0.0


print(f"""
    Player: {players_sample[0].get('player')}
    Profil : {extract_profil_type(players_sample[0].get('summary'))}
""")

print(f"""
    Player: {players_sample[0].get('player')}
    Profil : {normalize_text(extract_profil_type(players_sample[0].get('summary')))}
""")

print(f"""
    Player: {players_sample[0].get('player')}
    Profil : {canonical_tokens(extract_profil_type(players_sample[0].get('summary')))}
""")

player_1_index = 0
player_2_index = 3
profil_player_1 = extract_profil_type(players_sample[player_1_index].get('summary'))
profil_player_2 = extract_profil_type(players_sample[player_2_index].get('summary'))
token_player_1 = canonical_tokens(extract_profil_type(players_sample[player_1_index].get('summary')))
token_player_2 = canonical_tokens(extract_profil_type(players_sample[player_2_index].get('summary')))
print(f"""
    Players: {players_sample[player_1_index].get('player')} - {players_sample[player_2_index].get('player')}
    Tokens: {token_player_1} - {token_player_2}
    Score : {soft_label(profil_player_1, profil_player_2)}
""")
# Out:
#     Player: Nadiem Amiri
#     Profil : Milieu central polyvalent et créatif.
#
#
#     Player: Nadiem Amiri
#     Profil : milieu central polyvalent creatif
#
#
#     Player: Nadiem Amiri
#     Profil : {'milieu', 'central', 'polyvalent', 'creatif'}
#
#
#     Players: Nadiem Amiri - Danny da Costa
#     Tokens: {'milieu', 'central', 'polyvalent', 'creatif'} - {'defenseur', 'implique', 'central', 'solide'}
#     Score : 0

# %%
EVAL_PROMPT_TEMPLATE = """
Tu es recruteur dans un club professionnel.

Tu viens de lire un rapport de scouting décrivant le style de jeu, les qualités et les axes d’amélioration d’un joueur.

Formule une requête courte, naturelle et spécifique que taperait un recruteur pour retrouver ce profil :
- une seule phrase fluide
- poste (ou sous-rôle) + 2 ou 3 caractéristiques différenciantes
- termes précis : “pressing intense”, “relance propre”, “jeu entre les lignes”, “présence aérienne”, “percussion”, etc.
- ne sois pas vague (“bon techniquement” est à éviter)
- pas de nom, club, nationalité ou ligue

Résumé :
\"\"\"{summary}\"\"\"

Donne uniquement la requête, sans guillemets, sans commentaire.
"""

def generate_query_from_summary(summary: str, model: str):
    prompt = EVAL_PROMPT_TEMPLATE.format(summary=summary)
    resp = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "Tu es un assistant concis et précis."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.3,
        max_tokens=60
    )
    return resp.choices[0].message.content.strip()


try:
    with path.open("r", encoding="utf-8") as f:
        data = json.load(f)
        eval_queries = data if isinstance(data, list) else []
except FileNotFoundError:
    print("Le fichier n'existe pas")
    eval_queries = []
except json.JSONDecodeError:
    print('Le fichier est vide ou JSON corrompu ')
    eval_queries = []
    
for item in players_sample:
    connu = any(d.get("expected_player") == item.get('player') for d in eval_queries)
    if connu:
        continue
    
    q = generate_query_from_summary(item["summary"], model=config.Config.OPENAI_MODEL)
    eval_queries.append({
        "query": q,
        "expected_player": item["player"]
    })
    

print("Exemples de requêtes générées :")
for e in eval_queries[:3]:
    print("•", e["query"], "→ attendu :", e["expected_player"])
    
with open("../../data/player_queries.json", "w", encoding="utf-8") as f:
    json.dump(eval_queries, f, ensure_ascii=False, indent=2)
# Out:
# Exemples de requêtes générées :
# • défenseur central solide avec pressing intense, relance propre et bonne présence aérienne → attendu : William Saliba
# • milieu de terrain central avec pressing intense, relance propre et présence aérienne → attendu : Nicolás González
# • milieu central polyvalent avec pressing intense, relance propre et capacité à jouer entre les lignes → attendu : Bruno Guimarães

# %%
def build_profil_type() -> list[dict]:
    generated_list = {}
    next_page = None
    while True:
        points, next_page = qdrant_client.scroll(
            collection_name=collection_name,
            with_payload=True, with_vectors=False,
            limit=256, offset=next_page
        )
        for p in points:
            pl = p.payload or {}
            name = pl.get("player")
            if not name:
                continue
            profil = pl.get("profil_type") or extract_profil_type(pl.get("summary", ""))
            if profil:
                generated_list[name] = normalize_text(profil) 
        if not next_page:
            break
    return generated_list

profile_player = build_profil_type(players_sample)
profile_player
# Out:
# {'Ben White': 'defenseur central solide implique',
#  'Bukayo Saka': 'createur offensif polyvalent',
#  'David Raya': 'gardien but relanceur solide',
#  'Declan Rice': 'milieu creatif polyvalent',
#  'Ethan Nwaneri': 'attaquant creatif polyvalent',
#  'Gabriel Magalhães': 'defenseur central engage precis',
#  'Gabriel Martinelli': 'attaquant mobile creatif',
#  'Jakub Kiwior': 'defenseur central solide precis',
#  'Jurriën Timber': 'defenseur lateral offensif solide',
#  'Kai Havertz': 'attaquant polyvalent creatif',
#  'Leandro Trossard': 'attaquant creatif polyvalent',
#  'Martin Ødegaard': 'milieu creatif polyvalent',
#  'Mikel Merino': 'milieu offensif polyvalent creatif',
#  'Myles Lewis-Skelly': 'defenseur central solide fiable',
#  'Riccardo Calafiori': 'defenseur lateral offensif solide',
#  'Thomas Partey': 'milieu terrain polyvalent engage',
#  'William Saliba': 'defenseur central solide fiable',
#  'Amadou Onana': 'milieu central recuperateur dynamique',
#  'Boubacar Kamara': 'milieu terrain recuperateur distributeur',
#  'Diego Carlos': 'defenseur central solide fiable',
#  'Emiliano Martínez': 'gardien but solide fiable',
#  'Ezri Konsa': 'defenseur central engage precis',
#  'Ian Maatsen': 'defenseur lateral offensif solide',
#  'Jacob Ramsey': 'milieu offensif creatif polyvalent',
#  'John McGinn': 'milieu offensif creatif travailleur',
#  'Leon Bailey': 'attaquant creatif mobile',
#  'Lucas Digne': 'defenseur lateral offensif solide',
#  'Marco Asensio': 'milieu terrain creatif dynamique',
#  'Matty Cash': 'defenseur lateral engage polyvalent',
#  'Morgan Rogers': 'attaquant polyvalent creatif',
#  'Ollie Watkins': 'attaquant polyvalent creatif',
#  'Pau Torres': 'defenseur central solide implique',
#  'Tyrone Mings': 'defenseur central solide fiable',
#  'Youri Tielemans': 'milieu central creatif mobile',
#  'Adam Smith': 'defenseur central solide discipline',
#  'Alex Scott': 'milieu terrain defensif engage',
#  'Antoine Semenyo': 'attaquant mobile creatif',
#  'Dango Ouattara': 'attaquant mobile creatif',
#  'David Brooks': 'attaquant mobile creatif',
#  'Dean Huijsen': 'defenseur central solide implique',
#  'Evanilson': 'attaquant soutien polyvalent',
#  'Illia Zabarnyi': 'defenseur central solide fiable',
#  'Justin Kluivert': 'milieu offensif creatif dynamique',
#  'Kepa Arrizabalaga': 'gardien but solide fiable',
#  'Lewis Cook': 'milieu terrain polyvalent engage',
#  'Marcos Senesi': 'defenseur central solide engage',
#  'Marcus Tavernier': 'milieu offensif creatif engage',
#  'Milos Kerkez': 'defenseur lateral offensif solide',
#  'Ryan Christie': 'milieu central complet engage',
#  'Tyler Adams': 'milieu terrain box-to-box dynamique',
#  'Bryan Mbeumo': 'attaquant polyvalent creatif',
#  'Christian Nørgaard': 'milieu central complet engage',
#  'Ethan Pinnock': 'defenseur central solide fiable',
#  'Keane Lewis-Potter': 'defenseur lateral polyvalent engage',
#  'Kevin Schade': 'attaquant mobile creatif',
#  'Kristoffer Ajer': 'defenseur central solide fiable',
#  'Mads Roerslev': 'defenseur central creatif solide',
#  'Mark Flekken': 'gardien but relanceur solide',
#  'Mathias Jensen': 'milieu central polyvalent creatif',
#  'Mikkel Damsgaard': 'milieu terrain creatif polyvalent',
#  'Nathan Collins': 'defenseur central solide engage',
#  'Sepp van den Berg': 'defenseur central solide discipline',
#  'Vitaly Janelt': 'milieu central polyvalent creatif',
#  'Yehor Yarmoliuk': 'milieu defensif recuperateur discipline',
#  'Yoane Wissa': 'attaquant mobile creatif',
#  'Adam Webster': 'defenseur central solide fiable',
#  'Bart Verbruggen': 'gardien but solide relanceur',
#  'Carlos Baleba': 'milieu terrain box-to-box equilibre',
#  'Danny Welbeck': 'attaquant mobile creatif',
#  'Georginio Rutter': 'milieu terrain polyvalent creatif',
#  'Igor': 'defenseur central solide fiable',
#  'Jack Hinshelwood': 'milieu terrain polyvalent combatif',
#  'Jan Paul van Hecke': 'defenseur central solide fiable',
#  'João Pedro': 'attaquant polyvalent creatif',
#  'Joël Veltman': 'defenseur central solide discipline',
#  'Kaoru Mitoma': 'attaquant polyvalent creatif',
#  'Lewis Dunk': 'defenseur central solide fiable',
#  'Mats Wieffer': 'defenseur polyvalent engage',
#  "Matt O'Riley": 'milieu terrain box-to-box dynamique',
#  'Pervis Estupiñán': 'defenseur central solide engage',
#  'Simon Adingra': 'attaquant polyvalent creatif',
#  'Tariq Lamptey': 'defenseur lateral offensif creatif',
#  'Yankuba Minteh': 'attaquant creatif mobile',
#  'Yasin Ayari': 'milieu central polyvalent creatif',
#  'Christopher Nkunku': 'attaquant mobile creatif',
#  'Cole Palmer': 'milieu offensif creatif polyvalent',
#  'Enzo Fernández': 'milieu central polyvalent creatif',
#  'Jadon Sancho': 'attaquant soutien creatif mobile',
#  'Levi Colwill': 'defenseur central solide implique',
#  'Malo Gusto': 'defenseur central solide implique',
#  'Marc Cucurella': 'defenseur lateral offensif solide',
#  'Moisés Caicedo': 'milieu terrain polyvalent engage',
#  'Nicolas Jackson': 'attaquant mobile creatif',
#  'Noni Madueke': 'attaquant mobile creatif',
#  'Pedro Neto': 'attaquant creatif mobile',
#  'Reece James': 'defenseur polyvalent engage',
#  'Robert Sánchez': 'gardien but solide fiable',
#  'Roméo Lavia': 'milieu terrain recuperateur distributeur',
#  'Tosin Adarabioyo': 'defenseur central solide relanceur',
#  'Trevoh Chalobah': 'defenseur lateral engage solide',
#  'Wesley Fofana': 'defenseur central solide engage',
#  'Adam Wharton': 'milieu central creatif recuperateur',
#  'Chris Richards': 'defenseur central solide engage',
#  'Daichi Kamada': 'milieu terrain defensif polyvalent',
#  'Daniel Muñoz': 'defenseur lateral offensif dynamique',
#  'Dean Henderson': 'gardien but solide reactif',
#  'Eberechi Eze': 'milieu terrain creatif polyvalent',
#  'Eddie Nketiah': 'attaquant mobile creatif',
#  'Ismaila Sarr': 'milieu offensif creatif dynamique',
#  'Jean-Philippe Mateta': 'attaquant soutien creatif mobile',
#  'Jefferson Lerma': 'milieu terrain defensif polyvalent',
#  'Marc Guéhi': 'defenseur central solide engage',
#  'Maxence Lacroix': 'defenseur central engage solide',
#  'Tyrick Mitchell': 'defenseur central solide relanceur',
#  'Will Hughes': 'milieu central engage polyvalent',
#  'Abdoulaye Doucouré': 'milieu central polyvalent combatif',
#  'Ashley Young': 'defenseur lateral offensif solide',
#  'Beto': 'attaquant soutien mobile combatif',
#  'Carlos Alcaraz': 'attaquant polyvalent creatif',
#  'Dominic Calvert-Lewin': 'attaquant soutien creatif aerien',
#  'Dwight McNeil': 'milieu creatif polyvalent',
#  'Idrissa Gana Gueye': 'milieu central defensif distributeur',
#  'Iliman Ndiaye': 'attaquant soutien actif creatif',
#  'Jack Harrison': 'attaquant soutien creatif',
#  "Jake O'Brien": 'defenseur central solide fiable',
#  'James Garner': 'milieu terrain polyvalent defensif',
#  'James Tarkowski': 'defenseur central engage solide',
#  'Jarrad Branthwaite': 'defenseur central solide fiable',
#  'Jesper Lindstrøm': 'attaquant soutien creatif travailleur',
#  'Jordan Pickford': 'gardien but solide fiable',
#  'Michael Keane': 'defenseur central engage solide',
#  'Orel Mangala': 'milieu central polyvalent engage',
#  'Vitaliy Mykolenko': 'defenseur solide engage',
#  'Adama Traoré': 'attaquant creatif polyvalent',
#  'Alex Iwobi': 'attaquant polyvalent creatif',
#  'Andreas Pereira': 'milieu central creatif dynamique',
#  'Antonee Robinson': 'defenseur central solide constructif',
#  'Bernd Leno': 'gardien but fiable relanceur',
#  'Calvin Bassey': 'defenseur central solide fiable',
#  'Emile Smith Rowe': 'milieu terrain box-to-box dynamique',
#  'Harry Wilson': 'attaquant polyvalent opportuniste',
#  'Issa Diop': 'defenseur central solide precis',
#  'Joachim Andersen': 'defenseur central solide fiable',
#  'Kenny Tete': 'defenseur central solide implique',
#  'Raúl Jiménez': 'attaquant mobile creatif',
#  'Rodrigo Muniz': 'attaquant mobile efficace',
#  'Sander Berge': 'milieu defensif recuperateur discipline',
#  'Saša Lukić': 'milieu central solide creatif',
#  'Timothy Castagne': 'defenseur central solide engage',
#  'Alex Palmer': 'gardien but solide precis',
#  'Arijanet Muric': 'gardien but implique dans la construction',
#  'Axel Tuanzebe': 'defenseur central solide relanceur',
#  'Ben Johnson': 'defenseur lateral offensif polyvalent',
#  'Cameron Burgess': 'defenseur central solide relanceur',
#  'Conor Chaplin': 'milieu terrain creatif mobile',
#  "Dara O'Shea": 'defenseur central solide fiable',
#  'Jack Clarke': 'joueur creatif polyvalent',
#  'Jack Taylor': 'milieu terrain box-to-box dynamique',
#  'Jacob Greaves': 'defenseur central solide engage',
#  'Jens Cajuste': 'milieu central polyvalent engage',
#  'Julio Enciso': 'milieu terrain creatif dynamique',
#  'Kalvin Phillips': 'milieu defensif engage discipline',
#  'Leif Davis': 'defenseur central solide creatif',
#  'Liam Delap': 'attaquant mobile creatif',
#  'Luke Woolfenden': 'defenseur central solide engage',
#  'Omari Hutchinson': 'milieu terrain polyvalent creatif',
#  'Sam Morsy': 'milieu central polyvalent discipline',
#  'Sammie Szmodics': 'attaquant mobile creatif',
#  'Wes Burns': 'attaquant polyvalent engage',
#  'Bilal El Khannouss': 'milieu creatif polyvalent',
#  'Bobby De Cordova-Reid': 'attaquant soutien creatif',
#  'Boubakary Soumaré': 'milieu defensif recuperateur discipline',
#  'Caleb Okoli': 'defenseur central solide relanceur',
#  'Conor Coady': 'defenseur central solide precis',
#  'Facundo Buonanotte': 'attaquant mobile creatif',
#  'Harry Winks': 'milieu terrain central polyvalent',
#  'Jakub Stolarczyk': 'gardien but solide relanceur',
#  'James Justin': 'defenseur central engage solide',
#  'Jamie Vardy': 'attaquant mobile creatif',
#  'Jannik Vestergaard': 'defenseur central solide fiable',
#  'Jordan Ayew': 'attaquant mobile creatif',
#  'Kasey McAteer': 'attaquant soutien creatif',
#  'Luke Thomas': 'defenseur central solide engage',
#  'Mads Hermansen': 'gardien but solide relanceur',
#  'Oliver Skipp': 'milieu defensif engage precis',
#  'Patson Daka': 'attaquant mobile travailleur',
#  'Stephy Mavididi': 'attaquant finisseur mobile',
#  'Victor Bernth Kristiansen': 'defenseur central solide relanceur',
#  'Wilfred Ndidi': 'milieu central creatif recuperateur',
#  'Wout Faes': 'defenseur central solide engage',
#  'Alexis Mac Allister': 'milieu central polyvalent creatif',
#  'Alisson': 'gardien but solide fiable',
#  'Andrew Robertson': 'defenseur central implique dans la construction',
#  'Caoimhín Kelleher': 'gardien but solide fiable',
#  'Cody Gakpo': 'attaquant mobile creatif',
#  'Conor Bradley': 'defenseur central relanceur solide',
#  'Curtis Jones': 'milieu terrain polyvalent engage',
#  'Darwin Núñez': 'attaquant mobile creatif',
#  'Diogo Jota': 'attaquant mobile creatif',
#  'Dominik Szoboszlai': 'milieu terrain box-to-box dynamique',
#  'Ibrahima Konaté': 'defenseur solide relanceur',
#  'Kostas Tsimikas': 'defenseur lateral engage technique',
#  'Luis Díaz': 'attaquant mobile creatif',
#  'Mohamed Salah': 'attaquant polyvalent creatif',
#  'Ryan Gravenberch': 'milieu central recuperateur distributeur',
#  'Trent Alexander-Arnold': 'defenseur creatif engage',
#  'Virgil van Dijk': 'defenseur central solide implique',
#  'Bernardo Silva': 'milieu terrain creatif dynamique',
#  'Ederson': 'gardien but relanceur precis',
#  'Erling Haaland': 'attaquant mobile efficace',
#  'Jack Grealish': 'attaquant creatif mobile',
#  'Jeremy Doku': 'milieu offensif creatif dynamique',
#  'Joško Gvardiol': 'defenseur central solide engage',
#  'Kevin De Bruyne': 'milieu terrain creatif polyvalent',
#  'Kyle Walker': 'defenseur central solide precis',
#  'Manuel Akanji': 'defenseur central solide relanceur',
#  'Mateo Kovačić': 'milieu central complet creatif',
#  'Matheus Nunes': 'defenseur polyvalent creatif',
#  'Nicolás González': 'milieu offensif creatif travailleur',
#  'Omar Marmoush': 'attaquant creatif mobile',
#  'Phil Foden': 'milieu offensif polyvalent creatif',
#  'Rico Lewis': 'defenseur polyvalent engage',
#  'Rúben Dias': 'defenseur central solide fiable',
#  'Stefan Ortega': 'gardien but solide relanceur',
#  'Sávio': 'milieu offensif creatif polyvalent',
#  'İlkay Gündoğan': 'milieu terrain creatif discipline',
#  'Alejandro Garnacho': 'milieu offensif polyvalent creatif',
#  'Amad Diallo': 'milieu offensif creatif dynamique',
#  'André Onana': 'gardien but solide relanceur',
#  'Bruno Fernandes': 'milieu offensif creatif dynamique',
#  'Casemiro': 'milieu terrain box-to-box solide',
#  'Christian Eriksen': 'milieu central creatif engage',
#  'Diogo Dalot': 'defenseur central solide discipline',
#  'Harry Maguire': 'defenseur central solide engage',
#  'Joshua Zirkzee': 'attaquant creatif mobile',
#  'Kobbie Mainoo': 'milieu defensif engage recuperateur',
#  'Leny Yoro': 'defenseur central solide engage',
#  'Lisandro Martínez': 'defenseur central solide implique',
#  'Manuel Ugarte Ribeiro': 'milieu central polyvalent creatif',
#  'Marcus Rashford': 'attaquant creatif implique',
#  'Matthijs de Ligt': 'defenseur central solide discipline',
#  'Noussair Mazraoui': 'defenseur central solide engage',
#  'Patrick Dorgu': 'defenseur polyvalent engage',
#  'Rasmus Højlund': 'attaquant soutien creatif',
#  'Alexander Isak': 'attaquant polyvalent creatif',
#  'Anthony Gordon': 'attaquant polyvalent creatif',
#  'Bruno Guimarães': 'milieu central polyvalent creatif',
#  'Dan Burn': 'defenseur central solide implique',
#  'Fabian Schär': 'defenseur central solide engage',
#  'Harvey Barnes': 'attaquant mobile creatif',
#  'Jacob Murphy': 'attaquant creatif polyvalent',
#  'Joe Willock': 'milieu terrain polyvalent creatif',
#  'Joelinton': 'milieu terrain polyvalent engage',
#  'Kieran Trippier': 'defenseur central relanceur solide',
#  'Lewis Hall': 'defenseur central implique dans la relance',
#  'Martin Dúbravka': 'gardien but solide fiable',
#  'Nick Pope': 'gardien but solide relanceur',
#  'Sandro Tonali': 'milieu central polyvalent engage',
#  'Sean Longstaff': 'milieu defensif recuperateur sobre',
#  'Valentino Livramento': 'defenseur lateral solide fiable',
#  'Anthony Elanga': 'milieu offensif creatif implique',
#  'Callum Hudson-Odoi': 'attaquant polyvalent engage',
#  'Chris Wood': 'attaquant soutien creatif mobile',
#  'Elliot Anderson': 'milieu central polyvalent engage',
#  'Jota Silva': 'attaquant mobile creatif',
#  'Matz Sels': 'gardien but solide fiable',
#  'Morato': 'defenseur central solide discipline',
#  'Morgan Gibbs-White': 'milieu central creatif engage',
#  'Murillo': 'defenseur central solide engage',
#  'Neco Williams': 'defenseur central solide creatif',
#  'Nicolás Domínguez': 'milieu terrain polyvalent engage',
#  'Nikola Milenković': 'defenseur central solide implique',
#  'Ola Aina': 'defenseur lateral engage polyvalent',
#  'Ryan Yates': 'milieu terrain box-to-box solide',
#  'Álex Moreno': 'defenseur polyvalent engage',
#  'Aaron Ramsdale': 'gardien but solide fiable',
#  'Adam Armstrong': 'attaquant polyvalent creatif',
#  'Cameron Archer': 'attaquant soutien mobile creatif',
#  'Flynn Downes': 'milieu central defensif precis',
#  'Jack Stephens': 'defenseur central solide engage',
#  'James Bree': 'defenseur lateral solide technique',
#  'Jan Bednarek': 'defenseur central solide discipline',
#  'Joe Aribo': 'milieu terrain polyvalent engage',
#  'Kamaldeen Sulemana': 'milieu offensif polyvalent creatif',
#  'Kyle Walker-Peters': 'defenseur central solide precis',
#  'Lesley Ugochukwu': 'milieu central polyvalent discipline',
#  'Mateus Fernandes': 'milieu box-to-box dynamique engage',
#  'Nathan Wood-Gordon': 'defenseur central solide fiable',
#  'Paul Onuachu': 'attaquant mobile creatif',
#  'Ryan Manning': 'defenseur polyvalent engage',
#  'Taylor Harwood-Bellis': 'defenseur central solide fiable',
#  'Tyler Dibling': 'attaquant mobile creatif',
#  'Yukinari Sugawara': 'defenseur polyvalent engage',
#  'Archie Gray': 'defenseur polyvalent solide',
#  'Ben Davies': 'defenseur central solide fiable',
#  'Brennan Johnson': 'attaquant mobile creatif',
#  'Cristian Romero': 'defenseur central solide fiable',
#  'Dejan Kulusevski': 'milieu offensif creatif polyvalent',
#  'Destiny Udogie': 'defenseur lateral engage solide',
#  'Djed Spence': 'defenseur polyvalent engage',
#  'Dominic Solanke': 'attaquant mobile creatif',
#  'Guglielmo Vicario': 'gardien but relanceur fiable',
#  'James Maddison': 'milieu offensif creatif efficace',
#  'Kevin Danso': 'defenseur central solide fiable',
#  'Lucas Bergvall': 'milieu terrain recuperateur distributeur',
#  'Mathys Tel': 'attaquant mobile creatif',
#  'Micky van de Ven': 'defenseur central solide fiable',
#  'Pape Matar Sarr': 'milieu terrain polyvalent combatif',
#  'Pedro Porro': 'defenseur lateral offensif solide',
#  'Radu Drăgușin': 'defenseur central solide discipline',
#  'Rodrigo Bentancur': 'milieu defensif engage precis',
#  'Son Heung-min': 'attaquant creatif mobile',
#  'Wilson Odobert': 'attaquant polyvalent creatif',
#  'Yves Bissouma': 'milieu central polyvalent engage',
#  'Aaron Cresswell': 'defenseur central solide discipline',
#  'Aaron Wan-Bissaka': 'defenseur lateral offensif solide',
#  'Alphonse Areola': 'gardien but solide technique',
#  'Carlos Soler': 'milieu terrain creatif mobile',
#  'Crysencio Summerville': 'attaquant creatif mobile',
#  'Edson Álvarez': 'milieu terrain central polyvalent',
#  'Emerson Palmieri': 'defenseur central solide implique',
#  'Guido Rodríguez': 'milieu terrain box-to-box solide',
#  'James Ward-Prowse': 'milieu terrain creatif polyvalent',
#  'Jarrod Bowen': 'attaquant polyvalent creatif',
#  'Jean-Clair Todibo': 'defenseur central solide discipline',
#  'Konstantinos Mavropanos': 'defenseur central solide discipline',
#  'Lucas Paquetá': 'milieu terrain polyvalent engage',
#  'Max Kilman': 'defenseur central solide fiable',
#  'Michail Antonio': 'attaquant soutien creatif mobile',
#  'Mohammed Kudus': 'attaquant mobile creatif',
#  'Niclas Füllkrug': 'attaquant finisseur creatif',
#  'Tomáš Souček': 'milieu box-to-box dynamique',
#  'Vladimír Coufal': 'defenseur central solide engage',
#  'Łukasz Fabiański': 'gardien but solide securisant',
#  'André': 'milieu defensif recuperateur precis',
#  'Craig Dawson': 'defenseur central solide engage',
#  'Emmanuel Agbadou': 'defenseur central solide engage',
#  'Gonçalo Guedes': 'milieu offensif creatif mobile',
#  'Jean-Ricner Bellegarde': 'milieu terrain creatif polyvalent',
#  'José Sá': 'gardien but solide reactif',
#  'João Gomes': 'milieu central polyvalent discipline',
#  'Jørgen Strand Larsen': 'attaquant mobile creatif',
#  'Mario Lemina': 'milieu terrain polyvalent engage',
#  'Marshall Munetsi': 'milieu terrain box-to-box dynamique',
#  'Matheus Cunha': 'milieu offensif creatif dynamique',
#  'Matt Doherty': 'defenseur central solide implique',
#  'Nélson Semedo': 'defenseur lateral solide creatif',
#  'Pablo Sarabia': 'milieu terrain creatif polyvalent',
#  'Rayan Aït-Nouri': 'defenseur lateral offensif polyvalent',
#  'Rodrigo Gomes': 'defenseur lateral offensif engage',
#  'Santiago Bueno': 'defenseur central solide fiable',
#  'Toti Gomes': 'defenseur central solide engage',
#  'Abdel Abqar': 'defenseur central solide fiable',
#  'Ander Guevara': 'milieu terrain recuperateur distributeur',
#  'Antonio Blanco': 'milieu central recuperateur distributeur',
#  'Antonio Sivera': 'gardien but solide fiable',
#  'Carles Aleñá': 'milieu terrain creatif polyvalent',
#  'Carlos Martín': 'attaquant polyvalent creatif',
#  'Carlos Vicente': 'attaquant polyvalent creatif',
#  'Joan Jordán': 'milieu central polyvalent creatif',
#  'Jon Guridi': 'milieu terrain polyvalent creatif',
#  'Kiké': 'attaquant axial efficace creatif',
#  'Manu Sánchez': 'defenseur central engage relanceur',
#  'Moussa Diarra': 'defenseur central solide engage',
#  'Nahuel Tenaglia': 'defenseur central solide engage',
#  'Santiago Mouriño': 'defenseur central solide fiable',
#  'Tomás Conechny': 'attaquant creatif mobile',
#  'Toni Martínez': 'attaquant mobile creatif',
#  'Adama Boiro': 'defenseur polyvalent engage',
#  'Aitor Paredes': 'defenseur central solide fiable',
#  'Andoni Gorosabel': 'defenseur central solide implique',
#  'Beñat Prados': 'milieu central polyvalent recuperateur',
#  'Daniel Vivian': 'defenseur central solide precis',
#  'Gorka Guruzeta': 'attaquant soutien creatif',
#  'Iñaki Williams': 'attaquant creatif implique',
#  'Iñigo Lekue': 'defenseur central solide fiable',
#  'Iñigo Ruiz de Galarreta': 'milieu terrain creatif recuperateur',
#  'Julen Agirrezabala': 'gardien but solide organise',
#  'Maroan Sannadi': 'attaquant soutien polyvalent',
#  'Mikel Jauregizar': 'milieu central polyvalent engage',
#  'Mikel Vesga': 'milieu defensif engage polyvalent',
#  'Nico Williams': 'attaquant mobile creatif',
#  'Oihan Sancet': 'milieu offensif dynamique buteur',
#  'Unai Gómez': 'milieu terrain polyvalent creatif',
#  'Unai Simón': 'gardien but moderne implique',
#  'Yeray Álvarez': 'defenseur central solide fiable',
#  'Yuri Berchiche': 'defenseur central solide relanceur',
#  'Álex Berenguer': 'attaquant creatif polyvalent',
#  'Óscar de Marcos': 'defenseur central solide relanceur',
#  'Alexander Sørloth': 'attaquant finition efficace',
#  'Antoine Griezmann': 'attaquant polyvalent creatif',
#  'Axel Witsel': 'defenseur central solide implique',
#  'Clément Lenglet': 'defenseur central solide implique',
#  'Conor Gallagher': 'milieu central polyvalent engage',
#  'César Azpilicueta': 'defenseur central solide fiable',
#  'Giuliano Simeone': 'milieu creatif dynamique',
#  'Jan Oblak': 'gardien but fiable precis',
#  'Javi Galán': 'defenseur central solide implique',
#  'José María Giménez': 'defenseur central solide fiable',
#  'Julián Álvarez': 'attaquant polyvalent creatif',
#  'Koke': 'milieu terrain central creatif engage',
#  'Marcos Llorente': 'defenseur polyvalent engage',
#  'Nahuel Molina': 'defenseur central solide implique',
#  'Pablo Barrios': 'milieu central polyvalent engage',
#  'Reinildo Mandava': 'defenseur central solide engage',
#  'Robin Le Normand': 'defenseur central solide fiable',
#  'Rodrigo De Paul': 'milieu central creatif engage',
#  'Samuel Lino': 'milieu terrain polyvalent engage',
#  'Ángel Correa': 'attaquant polyvalent creatif',
#  'Alejandro Balde': 'defenseur central solide relanceur',
#  'Dani Olmo': 'milieu offensif polyvalent creatif',
#  'Eric García': 'defenseur polyvalent creatif',
#  'Fermin López': 'milieu offensif polyvalent creatif',
#  'Ferrán Torres': 'attaquant polyvalent creatif',
#  'Frenkie de Jong': 'milieu terrain creatif engage',
#  'Gavi': 'milieu terrain creatif technique',
#  'Gerard Martín': 'defenseur central polyvalent engage',
#  'Iñaki Peña': 'gardien but precis implique',
#  'Iñigo Martínez': 'defenseur central solide implique',
#  'Jules Koundé': 'defenseur lateral offensif solide',
#  'Lamine Yamal': 'attaquant creatif polyvalent',
#  'Marc Casado': 'milieu central creatif recuperateur',
#  'Pau Cubarsí': 'defenseur central solide precis',
#  'Pedri': 'milieu creatif distributeur',
#  'Raphinha': 'attaquant polyvalent creatif',
#  'Robert Lewandowski': 'attaquant finition efficace',
#  'Ronald Araújo': 'defenseur central solide implique',
#  'Wojciech Szczęsny': 'gardien but fiable precis',
#  'Abde Ezzalzouli': 'attaquant mobile creatif',
#  'Adrián': 'gardien but solide fiable',
#  'Aitor Ruibal': 'defenseur polyvalent creatif',
#  'Antony': 'attaquant mobile creatif',
#  'Cucho': 'attaquant mobile creatif',
#  'Diego Llorente': 'defenseur central solide fiable',
#  'Giovani Lo Celso': 'milieu creatif polyvalent',
#  'Isco': 'milieu offensif creatif travailleur',
#  'Jesus Rodríguez': 'attaquant mobile creatif',
#  'Johnny Cardoso': 'milieu terrain central polyvalent',
#  'Marc Bartra': 'defenseur central solide implique',
#  'Marc Roca': 'milieu central creatif engage',
#  'Natan': 'defenseur central solide engage',
#  'Pablo Fornals': 'milieu offensif creatif technique',
#  'Ricardo Rodríguez': 'defenseur central solide fiable',
#  'Romain Perraud': 'defenseur lateral implique creatif',
#  'Rui Silva': 'gardien but relanceur solide',
#  'Sergi Altimira': 'milieu terrain recuperateur distributeur',
#  'Vitor Roque': 'attaquant mobile opportuniste',
#  'Youssouf Sabaly': 'defenseur central solide fiable',
#  'Alfon': 'attaquant creatif implique',
#  'Borja Iglesias': 'attaquant mobile creatif',
#  'Carl Starfelt': 'defenseur solide implique',
#  'Carlos Dominguez': 'defenseur central solide fiable',
#  'Damián Rodríguez': 'milieu terrain central fiable',
#  'Fran Beltrán': 'milieu central polyvalent engage',
#  'Hugo Sotelo': 'milieu terrain central creatif',
#  'Hugo Álvarez': 'milieu terrain polyvalent creatif',
#  'Iago Aspas': 'attaquant creatif polyvalent',
#  'Ilaix Moriba': 'milieu central polyvalent discipline',
#  'Javi Rodríguez': 'defenseur central solide implique',
#  'Jonathan Bamba': 'milieu offensif creatif mobile',
#  'Marcos Alonso': 'defenseur central solide fiable',
#  'Pablo Durán': 'attaquant polyvalent creatif',
#  'Sergio Carreira': 'milieu terrain polyvalent engage',
#  'Vicente Guaita': 'gardien but solide fiable',
#  'Williot Swedberg': 'attaquant polyvalent creatif',
#  'Óscar Mingueza': 'milieu terrain polyvalent engage',
#  'Alejo Véliz': 'attaquant soutien polyvalent',
#  'Alex Král': 'milieu terrain central polyvalent',
#  'Antoniu': 'joueur creatif polyvalent',
#  'Brian Oliván': 'defenseur central implique dans la relance',
#  'Carlos Romero': 'defenseur central engage solide',
#  'Edu Expósito': 'milieu central creatif recuperateur',
#  'Javi Puado': 'attaquant polyvalent creatif',
#  'Joan García': 'gardien but solide relanceur',
#  'Jofre': 'milieu offensif creatif travailleur',
#  'Leandro Cabrera': 'defenseur solide implique',
#  'Marash Kumbulla': 'defenseur central solide discipline',
#  'Omar El Hilali': 'defenseur central solide discipline',
#  'Pol Lozano': 'milieu defensif solide discipline',
#  'Roberto Férnandez': 'attaquant soutien mobile creatif',
#  'Urko González': 'milieu terrain recuperateur distributeur',
#  'Álvaro Tejero': 'milieu terrain polyvalent engage',
#  'Alex Sola': 'milieu terrain polyvalent creatif',
#  'Allan Nyom': 'defenseur polyvalent solide',
#  'Bertuğ Yıldırım': 'attaquant soutien creatif',
#  'Borja Mayoral': 'attaquant mobile creatif',
#  'Carles Pérez': 'milieu terrain polyvalent creatif',
#  'Christantus Uche': 'attaquant polyvalent creatif',
#  'Coba da Costa': 'milieu terrain polyvalent creatif',
#  'David Soria': 'gardien but solide fiable',
#  'Diego Rico': 'defenseur central solide fiable',
#  'Djené': 'defenseur polyvalent engage',
#  'Domingos Duarte': 'defenseur central engage solide',
#  'Iglesias': 'defenseur central solide engage',
#  'Juan Berrocal': 'defenseur central solide discipline',
#  'Luis Milla': 'milieu central polyvalent engage',
#  'Mauro Arambarri': 'milieu terrain box-to-box dynamique',
#  'Omar Alderete': 'defenseur central solide relanceur',
#  'Ramón Terrats': 'milieu terrain polyvalent creatif',
#  'Álvaro Rodríguez': 'attaquant soutien actif creatif',
#  'Abel Ruiz': 'attaquant soutien efficace',
#  'Alejandro Francés': 'defenseur central solide engage',
#  'Arnau Martinez': 'defenseur polyvalent engage',
#  'Arnaut Danjuma': 'attaquant mobile creatif',
#  'Arthur Melo': 'milieu defensif engage technique',
#  'Bojan Miovski': 'attaquant mobile creatif',
#  'Bryan Gil': 'attaquant creatif mobile',
#  'Cristhian Stuani': 'attaquant mobile creatif',
#  'Daley Blind': 'defenseur central solide relanceur',
#  'David López': 'defenseur central solide implique',
#  'Donny van de Beek': 'milieu terrain creatif travailleur',
#  'Iván Martín': 'milieu central creatif precis',
#  'Juanpe': 'defenseur central solide discipline',
#  'Ladislav Krejčí': 'defenseur central solide fiable',
#  'Miguel Gutiérrez': 'defenseur polyvalent engage',
#  'Oriol Romeu': 'milieu terrain recuperateur distributeur',
#  'Paulo Gazzaniga': 'gardien but fiable precis',
#  'Portu': 'attaquant polyvalent creatif',
#  'Viktor Tsyhankov': 'attaquant creatif polyvalent',
#  'Yangel Herrera': 'milieu central polyvalent engage',
#  'Yaser Asprilla': 'attaquant mobile creatif',
#  'Alberto Moleiro': 'attaquant mobile creatif',
#  'Dario Essugo': 'milieu central defensif regulateur',
#  'Dinko Horkaš': 'gardien but relanceur solide',
#  'Fábio Silva': 'attaquant mobile creatif',
#  'Jasper Cillessen': 'gardien but solide fiable',
#  'Javier Muñoz': 'milieu terrain polyvalent engage',
#  'José Campaña': 'milieu terrain complet engage',
#  'Juan Herzog': 'defenseur central solide fiable',
#  'Kirian Rodríguez': 'milieu central polyvalent discipline',
#  'Manuel Fuster': 'attaquant creatif mobile',
#  'Marvin': 'defenseur polyvalent engage',
#  'Mika Mármol': 'defenseur central solide relanceur',
#  'Oliver McBurnie': 'attaquant soutien creatif',
#  'Sandro Ramírez': 'attaquant polyvalent creatif',
#  'Scott McKenna': 'defenseur central solide engage',
#  'Stefan Bajcetic': 'milieu terrain polyvalent defensif',
#  'Viti': 'defenseur lateral solide implique',
#  'Álex Muñoz': 'defenseur lateral solide engage',
#  'Álex Suárez': 'defenseur central solide discipline',
#  'Adrià Altimira': 'defenseur polyvalent engage',
#  'Dani Raba': 'attaquant polyvalent creatif',
#  'Darko Brašanac': 'milieu terrain central polyvalent',
#  'Diego': 'attaquant soutien creatif',
#  'Javi Hernández': 'defenseur central solide implique',
#  'Jorge Sáenz': 'defenseur solide engage',
#  'Juan Cruz': 'attaquant creatif polyvalent',
#  'Marko Dmitrović': 'gardien but solide precis',
#  'Matija Nastasić': 'defenseur central solide fiable',
#  'Miguel': 'attaquant soutien creatif',
#  'Munir El Haddadi': 'attaquant creatif mobile',
#  'Renato Tapia': 'milieu terrain defensif polyvalent',
#  'Sergi': 'defenseur central engage solide',
#  'Seydouba Cissé': 'milieu central polyvalent discipline',
#  'Valentin Rosier': 'defenseur central solide implique',
#  'Yvan Neyou': 'milieu central equilibre travailleur',
#  'Óscar Rodríguez Arnaiz': 'milieu terrain creatif polyvalent',
#  'Antonio Raillo': 'defenseur central solide fiable',
#  'Antonio Sánchez': 'milieu recuperateur defensif discipline',
#  'Copete': 'defenseur central solide engage',
#  'Cyle Larin': 'attaquant mobile creatif',
#  'Dani Rodríguez': 'milieu terrain creatif polyvalent',
#  'Dominik Greif': 'gardien but solide relanceur',
#  'Johan Mojica': 'defenseur central solide implique',
#  'Manu Morlanes': 'milieu defensif engage sobre',
#  'Martin Valjent': 'defenseur central solide engage',
#  'Mateu Morey': 'defenseur central solide discipline',
#  'Omar Mascarell': 'milieu terrain central polyvalent',
#  'Pablo Maffeo': 'defenseur central solide polyvalent',
#  'Roberto Navarro': 'milieu terrain polyvalent engage',
#  'Samu Costa': 'milieu central recuperateur distributeur',
#  'Sergi Darder': 'milieu terrain creatif polyvalent',
#  'Takuma Asano': 'attaquant creatif mobile',
#  'Vedat Muriqi': 'attaquant mobile creatif',
#  'Abel': 'defenseur central engage solide',
#  'Aimar Oroz': 'milieu terrain central polyvalent',
#  'Ante Budimir': 'attaquant axial efficace mobile',
#  'Bryan Zaragoza': 'milieu offensif creatif mobile',
#  'Catena': 'defenseur central solide engage',
#  'Enzo Boyomo': 'defenseur central solide fiable',
#  'Jesús Areso': 'defenseur central solide fiable',
#  'Jon Moncayola': 'milieu terrain recuperateur distributeur',
#  'Jorge Herrando': 'defenseur central solide fiable',
#  'Juan Cruz Armada': 'defenseur central solide discipline',
#  'Lucas Torró': 'milieu central polyvalent combatif',
#  'Moi Gómez': 'milieu terrain creatif travailleur',
#  'Pablo Ibáñez': 'milieu central polyvalent creatif',
#  'Raúl': 'attaquant polyvalent efficace',
#  'Rubén García': 'attaquant polyvalent creatif',
#  'Rubén Peña': 'attaquant polyvalent avec des capacites defensives',
#  'Sergio Herrera': 'gardien but solide implique',
#  'Abdul Mumin': 'defenseur central solide implique',
#  'Adri Embarba': 'attaquant soutien creatif',
#  'Alfonso Espino': 'defenseur lateral solide implique',
#  'Andrei Ratiu': 'defenseur central solide implique',
#  'Aridane Hernández': 'defenseur central solide fiable',
#  'Augusto Batalla': 'gardien but fiable relanceur',
#  'Florian Lejeune': 'defenseur central solide implique',
#  'Gerard Gumbau': 'milieu terrain recuperateur distributeur',
#  'Isaac Palazón Camacho': 'milieu terrain polyvalent creatif',
#  'Iván Balliu': 'defenseur central solide discipline',
#  'Jorge de Frutos': 'attaquant polyvalent creatif',
#  'Pathé Ciss': 'milieu terrain polyvalent engage',
#  'Pedro Díaz': 'milieu terrain creatif mobile',
#  'Pep Chavarría': 'defenseur polyvalent discipline',
#  'Randy Nteka': 'attaquant soutien actif travailleur',
#  'Sergio Camello': 'attaquant polyvalent creatif',
#  'Unai López': 'milieu central creatif engage',
#  'Álvaro García': 'attaquant creatif polyvalent',
#  'Óscar Valentín': 'milieu defensif engage sobre',
#  'Antonio Rüdiger': 'defenseur central solide precis',
#  'Arda Güler': 'milieu creatif polyvalent',
#  'Aurélien Tchouaméni': 'defenseur polyvalent solide',
#  'Brahim Díaz': 'attaquant polyvalent creatif',
#  'Dani Ceballos': 'milieu terrain central polyvalent',
#  'Eduardo Camavinga': 'milieu terrain polyvalent engage',
#  'Federico Valverde': 'milieu terrain polyvalent engage',
#  'Ferland Mendy': 'defenseur central solide precis',
#  'Fran Garcia': 'defenseur central solide discipline',
#  'Jude Bellingham': 'milieu creatif polyvalent',
#  'Kylian Mbappé': 'attaquant axial prolifique',
#  'Lucas Vázquez': 'defenseur lateral implique technique',
#  'Luka Modrić': 'milieu creatif polyvalent',
#  'Raúl Asencio': 'defenseur central solide fiable',
#  'Rodrygo': 'attaquant polyvalent creatif',
#  'Thibaut Courtois': 'gardien but solide fiable',
#  'Vinicius Júnior': 'attaquant creatif implique',
#  'Éder Militão': 'defenseur central solide relanceur',
#  'Aihen Muñoz': 'defenseur central solide engage',
#  'Ander Barrenetxea': 'milieu terrain creatif polyvalent',
#  'Aritz Elustondo': 'defenseur central solide fiable',
#  'Beñat Turrientes': 'milieu defensif solide discipline',
#  'Brais Méndez': 'milieu central polyvalent creatif',
#  'Igor Zubeldia': 'defenseur central solide fiable',
#  'Javi López': 'defenseur central solide discipline',
#  'Jon Aramburu': 'defenseur central solide relanceur',
#  'Jon Martin': 'defenseur central solide fiable',
#  'Jon Pacheco': 'defenseur central solide discipline',
#  'Luka Sučić': 'milieu central polyvalent engage',
#  'Martín Zubimendi': 'milieu central polyvalent engage',
#  'Mikel Oyarzabal': 'attaquant finisseur creatif',
#  'Nayef Aguerd': 'defenseur central solide engage',
#  'Olasagasti': 'milieu terrain box-to-box dynamique',
#  'Orri Steinn Óskarsson': 'attaquant soutien creatif mobile',
#  'Pablo Marín': 'milieu central creatif engage',
#  'Sergio Gómez': 'milieu polyvalent creatif',
#  'Sheraldo Becker': 'attaquant creatif mobile',
#  'Takefusa Kubo': 'milieu terrain creatif polyvalent',
#  'Álex Remiro': 'gardien but fiable precis',
#  'Adrià Pedrosa': 'defenseur central solide implique',
#  'Albert Sambi Lokonga': 'milieu central creatif recuperateur',
#  'Carmona': 'defenseur central solide engage',
#  'Chidera Ejuke': 'attaquant mobile creatif',
#  'Djibril Sow': 'milieu central polyvalent discipline',
#  'Dodi Lukebakio': 'attaquant mobile creatif',
#  'Isaac Romero': 'attaquant mobile creatif',
#  'Juanlu Sánchez': 'milieu terrain polyvalent combatif',
#  'Kike Salas': 'defenseur central solide implique',
#  'Loïc Bade': 'defenseur central solide fiable',
#  'Lucien Agoume': 'milieu central polyvalent combatif',
#  'Nemanja Gudelj': 'milieu terrain polyvalent defensif',
#  'Peque': 'milieu terrain creatif mobile',
#  'Saúl Ñíguez': 'milieu central creatif engage',
#  'Álvaro Fernández': 'gardien but solide relanceur',
#  'Ørjan Nyland': 'gardien but solide fiable',
#  'Cristhian Mosquera': 'defenseur central solide discipline',
#  'César Tárrega': 'defenseur central solide engage',
#  'Diego López': 'milieu terrain polyvalent creatif',
#  'Dimitri Foulquier': 'defenseur central solide discipline',
#  'Domingos André Ribeiro Almeida': 'milieu terrain creatif mobile',
#  'Enzo Barrenechea': 'milieu central polyvalent solide',
#  'Giorgi Mamardashvili': 'gardien but solide relanceur',
#  'Hugo Duro': 'attaquant soutien creatif',
#  'Javier Guerra': 'milieu central polyvalent engage',
#  'Jesus Vazquez': 'defenseur central solide implique',
#  'José Luis García Vayá': 'milieu central polyvalent engage',
#  'José Luis Gayà': 'defenseur central solide relanceur',
#  'Luis Rioja': 'milieu terrain creatif polyvalent',
#  'Rafa Mir': 'attaquant soutien creatif travailleur',
#  'Thierry Correia': 'defenseur central solide discipline',
#  'Umar Sadiq': 'attaquant soutien mobile creatif',
#  'Yarek Gasiorowski': 'defenseur central solide fiable',
#  'Adam Aznou': 'defenseur central solide discipline',
#  'Antonio Candela': 'defenseur central solide implique',
#  'Anuar': 'milieu terrain polyvalent creatif',
#  'Cenk Özkacar': 'defenseur central solide engage',
#  'Chuky san jose': 'milieu terrain central creatif',
#  'David Torres': 'defenseur central solide discipline',
#  'Eray Cömert': 'defenseur polyvalent solide',
#  'Iván Sánchez': 'milieu terrain creatif polyvalent',
#  'Javi Sánchez': 'defenseur central solide discipline',
#  'Juanmi Latasa': 'attaquant mobile avec potentiel creatif',
#  'Juma Bah': 'defenseur central solide fiable',
#  'Karl Jakob Hein': 'gardien but solide fiable',
#  'Kike Pérez': 'milieu central polyvalent discipline',
#  'Lucas Oliveira Rosa': 'defenseur central solide fiable',
#  'Luis Pérez': 'defenseur central solide discipline',
#  'Mamadou Sylla': 'attaquant mobile creatif',
#  'Marcos André': 'attaquant soutien creatif',
#  'Mario Martín': 'milieu terrain recuperateur distributeur',
#  'Raúl Moro': 'milieu terrain creatif polyvalent',
#  'Selim Amallah': 'milieu central polyvalent engage',
#  'Stanko Jurić': 'milieu defensif recuperateur precis',
#  'Tamás Nikitscher': 'milieu defensif solide engage',
#  'Alex Baena': 'milieu offensif creatif polyvalent',
#  'Ayoze Pérez': 'attaquant mobile efficace',
#  'Daniel Parejo': 'milieu central polyvalent discipline',
#  'Diego Conde': 'gardien but solide relanceur',
#  'Gerard Moreno': 'attaquant mobile creatif',
#  'Juan Foyth': 'defenseur central solide engage',
#  'Kiko Femenía': 'defenseur central solide fiable',
#  'Logan Costa': 'defenseur central solide engage',
#  'Luiz Lúcio Reis Júnior': 'gardien but solide fiable',
#  'Nicolas Pépé': 'createur offensif polyvalent',
#  'Pape Gueye': 'milieu terrain box-to-box dynamique',
#  'Pau Navarro': 'defenseur central solide discipline',
#  'Raúl Albiol': 'defenseur central solide discipline',
#  'Santi Comesaña': 'milieu central polyvalent engage',
#  'Sergi Cardona': 'defenseur lateral offensif solide',
#  'Thierno Barry': 'attaquant mobile creatif',
#  'Willy Kambwala': 'defenseur central solide fiable',
#  'Yeremi Pino': 'milieu terrain polyvalent creatif',
#  'Abdoulaye Bamba': 'defenseur central solide fiable',
#  'Carlens Arcus': 'defenseur central solide implique',
#  'Emmanuel Biumla': 'defenseur central solide fiable',
#  'Esteban Lepaul': 'attaquant soutien creatif',
#  'Farid El Melali': 'attaquant soutien creatif',
#  'Florent Hanin': 'defenseur central implique dans la relance',
#  'Haris Belkebla': 'milieu defensif engage sobre',
#  'Himad Abdelli': 'milieu terrain hybride creatif',
#  'Ibrahima Niane': 'attaquant mobile creatif',
#  'Jean-Eudes Aholou': 'milieu central polyvalent engage',
#  'Jim Allevinah': 'attaquant soutien creatif',
#  'Jordan Lefort': 'defenseur central solide fiable',
#  'Lilian Raolisoa': 'defenseur polyvalent engage',
#  'Yahia Fofana': 'gardien but solide relanceur',
#  'Yassin Belkhdim': 'milieu central equilibre defensif',
#  'Zinedine Ferhat': 'attaquant mobile creatif',
#  'Ado Onaiwu': 'milieu terrain hybride creatif',
#  'Clément Akpa': 'defenseur central solide engage',
#  'Donovan Léon': 'gardien but solide fiable',
#  'Elisha Owusu': 'milieu central polyvalent engage',
#  'Gabriel Osho': 'defenseur central solide fiable',
#  'Gaëtan Perrin': 'milieu offensif polyvalent creatif',
#  'Gideon Mensah': 'defenseur central solide engage',
#  'Hamed Junior Traorè': 'milieu offensif creatif dynamique',
#  'Han-Noah Massengo': 'milieu defensif engage sobre',
#  'Jubal': 'defenseur central engage solide',
#  'Ki-Jana Hoever': 'defenseur central solide engage',
#  'Kévin Danois': 'milieu terrain central polyvalent',
#  'Lassine Sinayoko': 'attaquant creatif polyvalent',
#  'Paul Joly': 'defenseur central solide discipline',
#  'Rayan Raveloson': 'milieu terrain polyvalent engage',
#  'Sinaly Diomande': 'defenseur central complet engage',
#  'Theo Bair': 'attaquant mobile creatif',
#  'Abdallah Sima': 'attaquant polyvalent creatif',
#  'Abdoulaye Niakhate Ndiaye': 'defenseur central solide fiable',
#  'Brendan Chardonnet': 'defenseur central solide relanceur',
#  'Edimilson Fernandes': 'milieu terrain defensif polyvalent',
#  'Hugo Magnetti': 'milieu central recuperateur constructif',
#  'Jordan Amavi': 'defenseur central engage solide',
#  'Julien Le Cardinal': 'defenseur central solide fiable',
#  'Kamory Doumbia': 'milieu terrain polyvalent creatif',
#  'Kenny Lala': 'defenseur central solide implique',
#  'Ludovic Ajorque': 'attaquant mobile creatif',
#  'Mahdi Camara': 'milieu terrain polyvalent actif',
#  'Mama Samba Baldé': 'attaquant mobile creatif',
#  'Marco Bizot': 'gardien but solide relanceur',
#  'Massadio Haïdara': 'defenseur central solide engage',
#  'Mathias Pereira Lage': 'attaquant creatif polyvalent',
#  'Pierre Lees-Melou': 'milieu central polyvalent creatif',
#  'Romain Del Castillo': 'attaquant mobile creatif',
#  'Romain Faivre': 'milieu terrain creatif polyvalent',
#  'Abdoulaye Touré': 'milieu offensif polyvalent engage',
#  'André Ayew': 'attaquant soutien polyvalent',
#  'Antoine Joujou': 'milieu terrain creatif engage',
#  'Arouna Sangante': 'defenseur central solide engage',
#  'Arthur Desmas': 'gardien but fiable precis',
#  'Christopher Operi': 'defenseur polyvalent engage',
#  'Etienne Youte Kinkoue': 'defenseur central solide fiable',
#  'Gautier Lloris': 'defenseur central solide relanceur',
#  'Issa Soumaré': 'attaquant polyvalent creatif',
#  'Josué Casimir': 'attaquant creatif polyvalent',
#  'Junior Mwanga': 'milieu central polyvalent engage',
#  'Koka': 'attaquant mobile creatif',
#  'Loïc Nego': 'defenseur lateral polyvalent engage',
#  'Mathieu Gorgelin': 'gardien but solide relanceur',
#  'Oussama Targhalline': 'milieu terrain central creatif',
#  'Rassoul Ndiaye': 'milieu central polyvalent combatif',
#  'Timothee Pembele': 'defenseur central solide discipline',
#  'Yanis Zouaoui': 'defenseur lateral implique creatif',
#  'Yassine Kechta': 'milieu terrain polyvalent engage',
#  'Yoann Salmier': 'defenseur central solide fiable',
#  'Abdukodir Khusanov': 'defenseur central solide engage',
#  'Adrien Thomasson': 'milieu central creatif engage',
#  'Anass Zaroury': 'attaquant creatif polyvalent',
#  'Andy Diouf': 'milieu terrain central polyvalent',
#  'Angelo Fulgini': 'milieu terrain creatif polyvalent',
#  'Brice Samba': 'gardien but solide implique',
#  'Deiver Machado': 'polyvalent defensif creatif',
#  'Facundo Medina': 'defenseur central solide fiable',
#  'Florian Sotoca': 'attaquant polyvalent creatif',
#  'Goduine Koyalipou': 'attaquant soutien creatif',
#  'Jonathan Gradit': 'defenseur central solide engage',
#  "M'Bala Nzola": 'attaquant mobile creatif',
#  'Malang Sarr': 'defenseur central solide rigoureux',
#  'Mathew Ryan': 'gardien but solide implique',
#  'Neil El Aynaoui': 'milieu offensif creatif travailleur',
#  'Przemysław Frankowski': 'defenseur lateral offensif polyvalent',
#  'Ruben Aguilar': 'defenseur polyvalent engage',
#  'Wesley Saïd': 'attaquant mobile soutenant',
#  'Alexsandro Ribeiro': 'defenseur central solide fiable',
#  'André Gomes': 'milieu terrain central fiable complet',
#  'Angel Gomes': 'milieu central polyvalent creatif',
#  'Ayyoub Bouaddi': 'milieu terrain recuperateur distributeur',
#  'Aïssa Mandi': 'defenseur central solide fiable',
#  'Bafodé Diakité': 'defenseur central solide implique',
#  'Benjamin André': 'milieu central polyvalent recuperateur',
#  'Edon Zhegrova': 'attaquant polyvalent creatif',
#  'Gabriel Gudmundsson': 'defenseur lateral offensif solide',
#  'Hákon Arnar Haraldsson': 'milieu terrain polyvalent creatif',
#  'Ismaily': 'defenseur central solide fiable',
#  'Jonathan David': 'attaquant polyvalent creatif',
#  'Lucas Chevalier': 'gardien but solide fiable',
#  'Matias Fernandez-Pardo': 'attaquant polyvalent creatif',
#  'Mitchel Bakker': 'attaquant polyvalent creatif',
#  "Ngal'Ayel Mukau": 'milieu terrain recuperateur distributeur',
#  'Osame Sahraoui': 'attaquant mobile creatif',
#  'Rémy Cabella': 'attaquant polyvalent creatif',
#  'Thomas Meunier': 'defenseur central solide engage',
#  'Abner': 'defenseur lateral offensif solide',
#  'Ainsley Maitland-Niles': 'defenseur lateral offensif solide',
#  'Alexandre Lacazette': 'attaquant soutien creatif mobile',
#  'Clinton Mata': 'defenseur central solide creatif',
#  'Corentin Tolisso': 'milieu central polyvalent creatif',
#  'Duje Ćaleta-Car': 'defenseur central solide fiable',
#  'Ernest Nuamah': 'attaquant polyvalent creatif',
#  'Georges Mikautadze': 'attaquant mobile creatif',
#  'Jordan Veretout': 'milieu central polyvalent travailleur',
#  'Lucas Perri': 'gardien but solide fiable',
#  'Malick Fofana': 'attaquant mobile creatif',
#  'Moussa Niakhate': 'defenseur central solide fiable',
#  'Nemanja Matić': 'milieu recuperateur efficace discipline',
#  'Nicolás Tagliafico': 'defenseur lateral offensif solide',
#  'Rayan Cherki': 'milieu offensif creatif dynamique',
#  'Sael Kumbedi': 'defenseur central solide engage',
#  'Saïd Benrahma': 'attaquant creatif polyvalent',
#  'Tanner Tessmann': 'milieu terrain central solide technique',
#  'Thiago Almada': 'milieu creatif polyvalent',
#  'Adrien Rabiot': 'milieu offensif creatif dynamique',
#  'Amine Gouiri': 'milieu offensif polyvalent creatif',
#  'Derek Cornelius': 'defenseur central solide precis',
#  'Geoffrey Kondogbia': 'defenseur polyvalent engage',
#  'Gerónimo Rulli': 'gardien but solide fiable',
#  'Jon Rowe': 'attaquant creatif polyvalent',
#  'Leonardo Balerdi': 'defenseur central solide precis',
#  'Lilian Brassier': 'defenseur central solide engage',
#  'Luis Henrique': 'defenseur polyvalent offensif',
#  'Mason Greenwood': 'attaquant polyvalent creatif',
#  'Michael Amir Murillo': 'defenseur central solide implique',
#  'Neal Maupay': 'attaquant polyvalent creatif',
#  'Pierre Højbjerg': 'milieu terrain complet engage',
#  'Quentin Merlin': 'defenseur central solide implique',
#  'Ulisses Garcia': 'defenseur lateral offensif solide',
#  'Valentin Rongier': 'milieu terrain polyvalent engage',
#  'Aleksandr Golovin': 'milieu terrain polyvalent creatif',
#  'Breel Embolo': 'attaquant creatif polyvalent',
#  'Caio Henrique Oliveira Silva': 'defenseur lateral offensif solide',
#  'Christian Mawissa': 'defenseur central solide fiable',
#  'Denis Zakaria': 'milieu central polyvalent creatif',
#  'Eliesse Ben Seghir': 'milieu terrain creatif dynamique',
#  'George Ilenikhena': 'attaquant mobile creatif',
#  'Lamine Camara': 'milieu central polyvalent creatif',
#  'Maghnes Akliouche': 'attaquant creatif polyvalent',
#  'Mika Biereth': 'attaquant efficace creatif',
#  'Mohammed Salisu': 'defenseur central solide engage',
#  'Philipp Köhn': 'gardien but solide relanceur',
#  'Radosław Majecki': 'gardien but solide relanceur',
#  'Soungoutou Magassa': 'milieu terrain central polyvalent',
#  'Takumi Minamino': 'milieu offensif polyvalent creatif',
#  'Thilo Kehrer': 'defenseur central solide relanceur',
#  'Vanderson': 'defenseur polyvalent solide',
#  'Wilfried Singo': 'defenseur central solide relanceur',
#  'Akor Adams': 'attaquant mobile creatif',
#  'Arnaud Nordin': 'attaquant mobile creatif',
#  'Becir Omeragic': 'defenseur central solide fiable',
#  'Benjamin Lecomte': 'gardien but solide relanceur',
#  'Boubakar Kouyaté': 'defenseur central solide engage',
#  'Enzo Tchato': 'defenseur central solide discipline',
#  'Falaye Sacko': 'defenseur central solide technique',
#  'Issiaga Sylla': 'defenseur central solide engage',
#  'Jordan Ferri': 'milieu terrain recuperateur distributeur',
#  'Joris Chotard': 'milieu terrain central polyvalent',
#  'Khalil Fayad': 'milieu terrain polyvalent engage',
#  'Modibo Sagnan': 'defenseur central solide engage',
#  'Musa Al-Taamari': 'attaquant creatif mobile',
#  'Rabby Nzingoula': 'milieu terrain box-to-box dynamique',
#  'Tanguy Coulibaly': 'attaquant mobile creatif',
#  'Théo Sainte-Luce': 'defenseur central solide engage',
#  'Téji Savanier': 'milieu central creatif engage',
#  'Wahbi Khazri': 'attaquant creatif polyvalent',
#  'Yael Mouanga': 'defenseur central solide discipline',
#  'Alban Lafont': 'gardien but solide fiable',
#  'Anthony Lopes': 'gardien but solide implique',
#  'Douglas': 'milieu central complet engage',
#  'Jean-Charles Castelletto': 'defenseur polyvalent solide',
#  'Johann Lepenant': 'milieu central polyvalent engage',
#  'Kelvin Amian': 'defenseur central solide engage',
#  'Louis Leroux': 'milieu terrain polyvalent combatif',
#  'Marcus Coco': 'defenseur central solide sobre',
#  'Matthis Abline': 'attaquant mobile creatif',
#  'Moses Simon': 'attaquant creatif polyvalent',
#  'Mostafa Mohamed': 'attaquant soutien polyvalent',
#  'Nathan Zeze': 'defenseur central solide fiable',
#  'Nicolas Cozza': 'defenseur polyvalent engage',
#  'Nicolas Pallois': 'defenseur central solide discipline',
#  'Pedro Chirivella': 'milieu central polyvalent discipline',
#  'Saidou Sow': 'defenseur central solide precis',
#  'Sorba Thomas': 'attaquant creatif mobile',
#  'Ali Abdi': 'defenseur polyvalent engage',
#  'Antoine Mendy': 'defenseur central solide discipline',
#  'Badredine Bouanani': 'milieu terrain polyvalent creatif',
#  'Baptiste Santamaria': 'milieu central defensif engage',
#  'Dante': 'defenseur central solide discipline',
#  'Evann Guessand': 'attaquant polyvalent creatif',
#  'Gaëtan Laborde': 'attaquant mobile creatif',
#  'Hicham Boudaoui': 'milieu central polyvalent engage',
#  'Jeremie Boga': 'milieu terrain creatif polyvalent',
#  'Jonathan Clauss': 'defenseur polyvalent engage',
#  'Marcin Bułka': 'gardien but solide relanceur',
#  'Melvin Bard': 'defenseur polyvalent engage',
#  'Mohamed Abdelmoneim': 'defenseur central solide fiable',
#  'Mohamed Ali Cho': 'attaquant mobile creatif',
#  'Moïse Bombito': 'defenseur central solide fiable',
#  'Pablo Rosario': 'milieu terrain polyvalent engage',
#  'Sofiane Diop': 'milieu offensif creatif polyvalent',
#  'Tanguy Ndombele': 'milieu terrain creatif solide',
#  'Tom Louchet': 'defenseur polyvalent engage',
#  'Youssouf Ndayishimiye': 'defenseur central solide fiable',
#  'Achraf Hakimi': 'defenseur lateral offensif creatif',
#  'Bradley Barcola': 'attaquant polyvalent creatif',
#  'Désiré Doué': 'attaquant polyvalent creatif',
#  'Fabián Ruiz Peña': 'milieu central creatif engage',
#  'Gianluigi Donnarumma': 'gardien but solide relanceur',
#  'Gonçalo Ramos': 'attaquant mobile creatif',
#  'João Neves': 'milieu terrain polyvalent creatif',
#  'Khvicha Kvaratskhelia': 'attaquant creatif implique',
#  'Lee Kang-in': 'attaquant creatif polyvalent',
#  'Lucas Beraldo': 'defenseur central solide technique',
#  'Lucas Hernández': 'defenseur central solide fiable',
#  'Marquinhos': 'defenseur central solide fiable',
#  'Matvei Safonov': 'gardien but solide relanceur',
#  'Nuno Mendes': 'defenseur central solide implique',
#  'Ousmane Dembélé': 'attaquant polyvalent creatif',
#  'Senny Mayulu': 'milieu central polyvalent creatif',
#  'Vitinha': 'attaquant mobile creatif',
#  'Warren Zaïre-Emery': 'milieu terrain polyvalent engage',
#  'Willian Pacho': 'defenseur central solide fiable',
#  'Amadou Koné': 'milieu defensif engage precis',
#  'Aurélio Buta': 'defenseur central solide fiable',
#  'Cédric Kipré': 'defenseur central solide fiable',
#  'Hiroki Sekine': 'defenseur central solide relanceur',
#  'Joseph Okumu': 'defenseur central solide fiable',
#  'Junya Ito': 'attaquant creatif polyvalent',
#  'Keito Nakamura': 'attaquant polyvalent creatif',
#  'Mamadou Diakhon': 'attaquant creatif mobile',
#  'Mory Gbane': 'defenseur polyvalent engage',
#  'Nhoa Sangui': 'defenseur polyvalent solide',
#  'Oumar Diakité': 'attaquant soutien creatif mobile',
#  'Sergio Akieme': 'defenseur central solide implique',
#  'Teddy Teuma': 'milieu central polyvalent defensif',
#  'Valentin Atangana Edoa': 'milieu central defensif engage',
#  'Yehvann Diouf': 'gardien but solide fiable',
#  'Adrien Truffert': 'defenseur polyvalent engage',
#  'Albert Grønbaek': 'milieu offensif creatif mobile',
#  'Alidu Seidu': 'defenseur central solide discipline',
#  'Anthony Rouault': 'defenseur central solide fiable',
#  'Arnaud Kalimuendo': 'attaquant polyvalent creatif',
#  'Azor Matusiwa': 'milieu central polyvalent discipline',
#  'Christopher Wooh': 'defenseur central solide discipline',
#  'Djaoui Cissé': 'milieu central polyvalent discipline',
#  'Hans Hateboer': 'defenseur central solide discipline',
#  'Jordan James': 'milieu central recuperateur distributeur',
#  'Jérémy Jacquet': 'defenseur central solide engage',
#  'Leo Skiri Østigård': 'defenseur central solide fiable',
#  'Lorenz Assignon': 'defenseur polyvalent creatif',
#  'Ludovic Blas': 'milieu terrain creatif polyvalent',
#  'Seko Fofana': 'milieu central creatif solide',
#  'Steve Mandanda': 'gardien but solide relanceur',
#  'Aimen Moueffek': 'milieu terrain recuperateur distributeur',
#  'Augustine Boakye': 'attaquant creatif mobile',
#  'Benjamin Bouchouari': 'milieu central equilibre recuperateur',
#  'Dennis Appiah': 'defenseur central solide implique',
#  'Dylan Batubinsika': 'defenseur central solide fiable',
#  'Florian Tardieu': 'milieu central creatif engage',
#  'Gautier Larsonneur': 'gardien but solide relanceur',
#  'Ibrahim Sissoko': 'attaquant mobile creatif',
#  'Irvin Cardona': 'attaquant mobile creatif',
#  'Louis Mouton': 'milieu terrain recuperateur distributeur',
#  'Lucas Stassin': 'attaquant mobile creatif',
#  ...}

# %%
def eval_ndcg_profil(eval_queries, k, gain_exact=GAIN_EXACT_PLAYER) -> dict:
    scores, details = [], []
    for sample in eval_queries:
        query = sample['query']
        expected = sample['expected_player']
        
        expected_profile = profile_player.get(expected, None)
        
        if expected_profile == None: 
            print(expected)
            continue
        
        query_vector = embedding_model.encode(query).tolist()
        results = qdrant_client.query_points(collection_name=collection_name, query=query_vector, limit=k)
        
        gains, cand_list = [], []
        for point in results.points: 
            payload = point.payload or {}
            cand_name = payload.get('player')
            cand_profile = normalize_text(extract_profil_type(payload.get('summary')))
            
            cand_list.append({'player':cand_name, 'profil_type': cand_profile})
            
            if cand_name == expected:
                gains.append(gain_exact)
            else:
                if expected_profile:
                    gains.append(soft_label(expected_profile, cand_profile))
                else:
                    gains.append(soft_label(query, cand_profile))
            
        ndcg = ndcg_at_k(gains, k)
        scores.append(ndcg)
        details.append({
            "query": query,
            "expected_player": sample["expected_player"],
            "ref_profil": expected_profile,
            "candidates": cand_list,
            "gains": gains,
            f"nDCG@{k}": round(ndcg, 3)
        })
    
    return {f"nDCG@{k}": round(sum(scores)/len(scores), 3), "details": details}

k = 3
name = f"nDCG@{k}"       
report = eval_ndcg_profil(eval_queries, k)
print(f"{name} = {report[name]}")
# Out:
# /Users/florian/.pyenv/versions/scout_rag_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# nDCG@3 = 0.93

# %%
from collections import Counter
all_gains = []
for d in report["details"]:
    all_gains.extend(d["gains"])
print(Counter(all_gains))
# Out:
# Counter({2: 150, 3: 91, 1: 49, 0: 26, 4: 5})

# %%
## LLM as Judge
K = 5 

def retrieve_topk(query: str, k: int = K):
    qvec = embedding_model.encode(query).tolist()
    results = qdrant_client.query_points(
        collection_name=collection_name,
        query=qvec,
        limit=k
    )

    candidates = []
    for r in results.points:
        pl = r.payload or {}
        candidates.append({
            "player": pl.get("player"),
            "profil_type": extract_profil_type(pl.get("summary")),
            "summary": pl.get("summary", "")
        })
    return candidates


def clip(txt: str, n: int = 500) -> str:
    txt = txt.strip()
    return (txt[:n] + "…") if len(txt) > n else txt

JUDGE_PROMPT = """
    Tu es évaluateur de pertinence pour le recrutement football.

    Consigne : pour une requête donnée, on te fournit une liste de candidats (profil-type + extrait de résumé).
    Attribue une note de pertinence entière à chacun des candidats, dans {0,1,2,3} :
    - 0 = hors sujet
    - 1 = partiellement pertinent (une seule caractéristique correspond)
    - 2 = pertinent (bon match global)
    - 3 = très pertinent (profil idéal pour la requête)

    Règles :
    - Juge uniquement d’après la requête et la description fournie.
    - Pas de suppositions : si c’est ambigu, note plus bas.
    - Réponse attendue : UNIQUEMENT une liste JSON d’entiers de longueur K, par ex: [2,1,0,3,2]
"""

def judge_relevance_llm(query: str, candidates: list[dict], model: str) -> list[int]:
    lines = [f"Requête: {query}", "", "Candidats:"]
    for i, c in enumerate(candidates, start=1):
        ptype = c.get("profil_type") or ""
        summ = clip(c.get("summary",""), 450)
        lines.append(f"{i}. Profil-type: {ptype if ptype else '(non précisé)'}")
        lines.append(f" Résumé: {summ}")
    lines.append("")
    lines.append("Rends uniquement la liste JSON des notes, rien d’autre.")

    prompt = JUDGE_PROMPT + "\n" + "\n".join(lines)

    resp = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "Tu es strict, cohérent et concis."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.0,
        max_tokens=50
    )
    text = resp.choices[0].message.content.strip()

    try:
        scores = json.loads(text)
    except Exception:
        # fallback: extraire la 1ère liste [ ... ] d'entiers
        m = re.search(r"\[(\s*\d\s*(?:,\s*\d\s*)*)\]", text)
        scores = [int(x) for x in m.group(1).split(",")] if m else []

    if len(scores) != len(candidates):
        scores = (scores + [0]*len(candidates))[:len(candidates)]
    scores = [max(0, min(3, int(x))) for x in scores]
    return scores

def ndcg_at_k(gains: list[int], k: int) -> float:
    gains = gains[:k]
    dcg = sum(g / math.log2(i + 2) for i, g in enumerate(gains))
    ideal = sorted(gains, reverse=True)
    idcg = sum(g / math.log2(i + 2) for i, g in enumerate(ideal))
    return (dcg / idcg) if idcg > 0 else 0.0

def eval_llm_judge(eval_queries: list[dict], judge_model: str, k: int = K, max_queries: int = 10):
    ndcgs = []
    judged_details = []

    subset = eval_queries[:max_queries]  # on démarre sur 10
    for sample in subset:
        query = sample["query"]
        candidates = retrieve_topk(query, k=k)
        gains = judge_relevance_llm(query, candidates, model=judge_model)

        ndcg = ndcg_at_k(gains, k)
        ndcgs.append(ndcg)

        judged_details.append({
            "query": query,
            "candidates": [{"player": c["player"], "profil_type": c["profil_type"]} for c in candidates],
            "gains": gains,
            f"nDCG@{k}": round(ndcg, 3)
        })

    return {
        f"nDCG@{k}": round(sum(ndcgs)/len(ndcgs), 3) if ndcgs else 0.0,
        "details": judged_details
    }

# %%
report_judge = eval_llm_judge(
    eval_queries=eval_queries,
    judge_model=config.Config.OPENAI_MODEL,
    k=5,
    max_queries=10
)

print("LLM-judge nDCG@5:", report_judge["nDCG@5"])
for d in report_judge["details"][:3]:
    print("\nQ:", d["query"])
    print("Gains:", d["gains"])
    print("TopK:", [(c["player"], c["profil_type"]) for c in d["candidates"]])
# Out:
# /Users/florian/.pyenv/versions/scout_rag_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# LLM-judge nDCG@5: 0.918
#
# Q: défenseur central solide avec pressing intense, relance propre et bonne présence aérienne
# Gains: [2, 2, 1, 1, 2]
# TopK: [('Marquinhos', 'Défenseur central solide et fiable.'), ('Cameron Burgess', 'Défenseur central solide et relanceur.'), ('Taylor Harwood-Bellis', 'Défenseur central solide et fiable.'), ('Adam Masina', 'Défenseur central solide et fiable.'), ('Abdukodir Khusanov', 'Défenseur central solide et engagé.')]
#
# Q: milieu de terrain central avec pressing intense, relance propre et présence aérienne
# Gains: [2, 2, 1, 2, 3]
# TopK: [('Elliot Anderson', 'Milieu central polyvalent et engagé.'), ('Seydouba Cissé', 'Milieu central polyvalent et discipliné.'), ('Arne Maier', 'Milieu central sobre et travailleur.'), ('Youssouf Fofana', 'Milieu central créatif et engagé.'), ('Ondrej Duda', 'Milieu central créatif et engagé.')]
#
# Q: milieu central polyvalent avec pressing intense, relance propre et capacité à jouer entre les lignes
# Gains: [2, 2, 2, 3, 1]
# TopK: [('Enzo Fernández', 'Milieu central polyvalent et créatif.'), ('Bruno Guimarães', 'Milieu central polyvalent et créatif.'), ('Rolando Mandragora', 'Milieu central polyvalent et créatif.'), ('Michel Ndary Adopo', 'Milieu central polyvalent et engagé.'), ('Manuel Locatelli', 'Milieu central polyvalent et récupérateur.')]
